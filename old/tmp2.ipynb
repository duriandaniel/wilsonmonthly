# %%
import pdfplumber

with pdfplumber.open("12.-June-2025_WAR.pdf") as pdf:
    text = "\n".join(p.extract_text() or "" for p in pdf.pages)
print(text)
# Out:
# Cannot set gray non-stroke color because /'P229' is an invalid float value
# Cannot set gray non-stroke color because /'P271' is an invalid float value
# 126.52c 125.85 0.67c
# 123.53c
# $1.50
# per share
# 6.0c 15.75c 22.5c
# 5.6% 8.0% 16.3c
# $230.7m $1.075 +33.3%
# Closed book outline
# Interim Result Interim Financial Report
# 19.5%
# 1.6%
# 5.6%
# 55.3%
# 18.0%
# 04
# 01 02 03
# >$5.9 billion
# 130,000
# >250 years
# 11
